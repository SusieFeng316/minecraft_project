# %% [markdown]
# # Individual Plan Susie

# %% [markdown]
# [github link](https://github.com/SusieFeng316/minecraft_project.git)

# %%
library(tidyverse)
# Out:
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.4     ✔ readr     2.1.5
# ✔ forcats   1.0.0     ✔ stringr   1.5.1
# ✔ ggplot2   3.5.1     ✔ tibble    3.2.1
# ✔ lubridate 1.9.3     ✔ tidyr     1.3.1
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors

# %%
players <- read_csv("players.csv")
players
sessions <- read_csv("sessions.csv")
sessions
# Out:
# Rows: 196 Columns: 7
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (4): experience, hashedEmail, name, gender
# dbl (2): played_hours, Age
# lgl (1): subscribe
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#     experience subscribe
# 1   Pro         TRUE
# 2   Veteran     TRUE
# 3   Veteran    FALSE
# 4   Amateur     TRUE
# 5   Regular     TRUE
# 6   Amateur     TRUE
# 7   Regular     TRUE
# 8   Amateur    FALSE
# 9   Amateur     TRUE
# 10  Veteran     TRUE
# 11  Veteran     TRUE
# 12  Pro         TRUE
# 13  Beginner    TRUE
# 14  Amateur     TRUE
# 15  Veteran     TRUE
# 16  Amateur    FALSE
# 17  Beginner    TRUE
# 18  Amateur     TRUE
# 19  Amateur     TRUE
# 20  Regular     TRUE
# 21  Regular     TRUE
# 22  Amateur    FALSE
# 23  Beginner    TRUE
# 24  Beginner    TRUE
# 25  Amateur     TRUE
# ...

# %%
players |> summarize(max(played_hours), min(played_hours),mean(played_hours), 
                     max_age = max(Age, na.rm= TRUE),  mean_age = mean(Age,na.rm= TRUE), min_age = min(Age,na.rm= TRUE))
# Out:
#   max(played_hours) min(played_hours) mean(played_hours) max_age mean_age
# 1 223.1             0                 5.845918           58      21.13918
#   min_age
# 1 9

# %% [markdown]
# # (1) Data Description
# The "players.csv" dataset contains 196 observations and 7 columns/variables.
# + `experience` is in character form. It is level of expertise in game.
# + `subscribe` is in logical form. The column indicates whether or not they subscribed to game-related newsletter
# + `hashedEmail` is in character form. It is encrypted email address of players.
# + `played_hours` is in double form. It is the number of hours the gamers play in plaicraft. The mean played hours is 5.85, with the maximum hour being 223.10 and the minimum hour is 0.00.
# + `name` is in character form. It specifies the name of the gamers.
# + `gender` is in character form and states the gender of players.
# + `Age` is in double form. It's the age of the players. The mean age is 21.14 years old, with the maximum age being 58.00, the minimum age being 9.00.
#
# The "sessions.csv" dataset contains 1535 observations and 5 columns/variables.
# + `hashedEmail`is in character form. It is encrypted email address of players.
# + `start_time` is in character form. It is the date and time when the players start playing.
# + `end_time` is in character form. It is the date and time when the players stop playing.
# + `original_start_time` is in double form. It's start time in numerical form.
# + `original_end_time`is in double form. It's end time in numerical form.
#
# An issue I see is that there are "N/A" in the Age column that needs to be get rid off using `na.rm = TRUE`
# Another issue is hashed email isn't understandable and should be removed.
# A potential issue would be as there is only 196 observations, the dataset is small so that the model produced might overfit.
# Both datasets are collected from people who consent to participate in the study.

# %% [markdown]
# # (2) Questions
# The broad question I choose is question 1. The specific question is "Can `played_hours`, `gender`, `Age` predict whether a person subscribes to newsletter and how do these features differ between various player types in "players.csv" dataset?
# The columns `played_hours`, `gender`, `Age`,`subscribe`, and `experience` will be used, so I'll use select to remove the rest of the columns. Since there is too little data for genders other than `Male` and `Female`, I will combine the rest and call it `Other`. To do so, gender should be in factor form.
#
# Describe clearly how the data will help you address the question of interest. You may need to describe how you plan to wrangle your data to get it into a form where you can apply one of the predictive methods from this class

# %% [markdown]
# # (3) Exploratory Data Analysis and Visualization

# %%
players <- players |>
select(-hashedEmail,-name)|>
  mutate(gender = as.factor(gender)) |>
  mutate(gender = fct_collapse(
    gender,
    Male = c("Male"),
    Female = c("Female"),
    Other = c("Non-binary", "Other", "Two-Spirited", "Prefer not to say","Agender")))
players
# Out:
#     experience subscribe played_hours gender Age
# 1   Pro         TRUE     30.3         Male    9
# 2   Veteran     TRUE      3.8         Male   17
# 3   Veteran    FALSE      0.0         Male   17
# 4   Amateur     TRUE      0.7         Female 21
# 5   Regular     TRUE      0.1         Male   21
# 6   Amateur     TRUE      0.0         Female 17
# 7   Regular     TRUE      0.0         Female 19
# 8   Amateur    FALSE      0.0         Male   21
# 9   Amateur     TRUE      0.1         Male   47
# 10  Veteran     TRUE      0.0         Female 22
# 11  Veteran     TRUE      1.6         Female 23
# 12  Pro         TRUE      0.0         Male   17
# 13  Beginner    TRUE      1.5         Female 25
# 14  Amateur     TRUE      0.2         Male   22
# 15  Veteran     TRUE      0.0         Other  17
# 16  Amateur    FALSE      0.0         Male   22
# 17  Beginner    TRUE      0.0         Female 17
# 18  Amateur     TRUE     48.4         Female 17
# ...

# %%
players |> summarize(mean(played_hours), 
                    mean_age = mean(Age,na.rm= TRUE))
# Out:
#   mean(played_hours) mean_age
# 1 5.845918           21.13918

# %%
ggplot(players, aes(x = Age, fill = experience)) +
  geom_histogram(position = "identity", bins = 30)+ facet_grid(rows = vars(experience))+
xlab("Players' Age (year)")+
ylab("Experience")+
ggtitle("Histogram of players' age versus experience")
# Out:
# Warning message:
# “Removed 2 rows containing non-finite outside the scale range (`stat_bin()`).”
# plot without title

# %% [markdown]
# Players with veteran, regular and pro experience has slightly smaller mean age than players with amateur and beginner experience.

# %%
ggplot(players, aes(x=subscribe)) + geom_bar(aes(fill=gender), position="dodge")+
xlab("Subscribe")+
ylab("Gender")+
ggtitle("Bar graph of gender versus whether they subscribe")
# Out:
# plot without title

# %% [markdown]
# There is greater number of male who subscribe than not subscribe versus that of female and others.

# %%
ggplot(players, aes(x = Age, y = played_hours, color = subscribe)) +
  geom_point()+
xlab("Age(year)")+
ylab("Played Time (hours)")+
ggtitle("Scatter plot of age versus played time in hours")
# Out:
# Warning message:
# “Removed 2 rows containing missing values or values outside the scale range
# (`geom_point()`).”
# plot without title

# %% [markdown]
# Played_hours and age are two predictors used to predict subscribe. As played hours increase, subscription increases. As age increase, people who subscribe decreases.

# %% [markdown]
# # (4) Methods and Plan
# I will use knn classification. It is appropriate since the predicted variable `subscribe` is a categorical variable. No assumption is required. A weakness would be the result isn't interpretable. I’m going to use tune() to select k and compare the accuracy, precision, and recall to determine the best predictor for `subscribe`.
# I will split data at the first stage of modelling into two splits with `prop = 0.75`. I will do cross validation into 5 folds and will have 5 validation sets.
